# %% [markdown]
# Gini index and spit the dataset.
# Example from Jason Brownlee.
# Detailed output for understanding the process.

# %%
def test_split(index, value, dataset):
    left, right = list(), list()
    for row in dataset:
        if row[index] < value:
            left.append(row)
        else:
            right.append(row)
    return left, right

# %%
def gini_index(groups, classes):
    n_instances = float(sum([len(group) for group in groups]))
    gini = 0.0
    for group in groups:
        size = float(len(group))
        if size==0:
            continue
        score = 0.0
        for class_val in classes:
            p = [row[-1] for row in group].count(class_val)/size
            score +=p*p
            print('class_val=%d '% (class_val))
            print('size=%d '% (size))
            print('p=%.3f '% (p))
            print('score=%.3f '% (score))

        gini += (1.0 - score)*(size/n_instances)
        
    return gini

# %%
def get_split(dataset):
    class_values = list(set(row[-1] for row in dataset))
    b_index, b_value, b_score, b_groups = 999, 999, 999, None
    for index in range(len(dataset[0])-1):
        for row in dataset:
            groups = test_split(index, row[index], dataset)
            gini = gini_index(groups, class_values)
            print('X%d < %.3f Gini=%.3f'% ((index+1), row[index], gini))
            print('index=%d  value=%.3f '% (index, row[index]))
            print(*groups)
            print(' ')

            if gini <b_score:
                b_index, b_value, b_score, b_groups= index, row[index], gini, groups
    return {'index':b_index, 'value':b_value, 'groups':b_groups}

# %%
dataset = [[2.771244718,1.784783929,0],
[1.728571309,1.169761413,0],
[3.678319846,2.81281357,0],
[3.961043357,2.61995032,0],
[2.999208922,2.209014212,0],
[7.497545867,3.162953546,1],
[9.00220326,3.339047188,1],
[7.444542326,0.476683375,1],
[10.12493903,3.234550982,1],
[6.642287351,3.319983761,1]]

split = get_split(dataset)
print('Split: [X%d < %.3f]' % ((split['index']+1), split['value']))
# Out:
# class_val=0
# size=1
# p=1.000
# score=1.000
# class_val=1
# size=1
# p=0.000
# score=1.000
# class_val=0
# size=9
# p=0.444
# score=0.198
# class_val=1
# size=9
# p=0.556
# score=0.506
# X1 < 2.771 Gini=0.444
# index=0  value=2.771
# [[1.728571309, 1.169761413, 0]] [[2.771244718, 1.784783929, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=10
# p=0.500
# score=0.250
# class_val=1
# size=10
# p=0.500
# score=0.500
# X1 < 1.729 Gini=0.500
# index=0  value=1.729
# [] [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=3
# p=1.000
# score=1.000
# class_val=1
# size=3
# p=0.000
# score=1.000
# class_val=0
# size=7
# p=0.286
# score=0.082
# class_val=1
# size=7
# p=0.714
# score=0.592
# X1 < 3.678 Gini=0.286
# index=0  value=3.678
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [2.999208922, 2.209014212, 0]] [[3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=4
# p=1.000
# score=1.000
# class_val=1
# size=4
# p=0.000
# score=1.000
# class_val=0
# size=6
# p=0.167
# score=0.028
# class_val=1
# size=6
# p=0.833
# score=0.722
# X1 < 3.961 Gini=0.167
# index=0  value=3.961
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [2.999208922, 2.209014212, 0]] [[3.961043357, 2.61995032, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=2
# p=1.000
# score=1.000
# class_val=1
# size=2
# p=0.000
# score=1.000
# class_val=0
# size=8
# p=0.375
# score=0.141
# class_val=1
# size=8
# p=0.625
# score=0.531
# X1 < 2.999 Gini=0.375
# index=0  value=2.999
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0]] [[3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=7
# p=0.714
# score=0.510
# class_val=1
# size=7
# p=0.286
# score=0.592
# class_val=0
# size=3
# p=0.000
# score=0.000
# class_val=1
# size=3
# p=1.000
# score=1.000
# X1 < 7.498 Gini=0.286
# index=0  value=7.498
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.444542326, 0.476683375, 1], [6.642287351, 3.319983761, 1]] [[7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1]]
#
# class_val=0
# size=8
# p=0.625
# score=0.391
# class_val=1
# size=8
# p=0.375
# score=0.531
# class_val=0
# size=2
# p=0.000
# score=0.000
# class_val=1
# size=2
# p=1.000
# score=1.000
# X1 < 9.002 Gini=0.375
# index=0  value=9.002
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [7.444542326, 0.476683375, 1], [6.642287351, 3.319983761, 1]] [[9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1]]
#
# class_val=0
# size=6
# p=0.833
# score=0.694
# class_val=1
# size=6
# p=0.167
# score=0.722
# class_val=0
# size=4
# p=0.000
# score=0.000
# class_val=1
# size=4
# p=1.000
# score=1.000
# X1 < 7.445 Gini=0.167
# index=0  value=7.445
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [6.642287351, 3.319983761, 1]] [[7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1]]
#
# class_val=0
# size=9
# p=0.556
# score=0.309
# class_val=1
# size=9
# p=0.444
# score=0.506
# class_val=0
# size=1
# p=0.000
# score=0.000
# class_val=1
# size=1
# p=1.000
# score=1.000
# X1 < 10.125 Gini=0.444
# index=0  value=10.125
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [6.642287351, 3.319983761, 1]] [[10.12493903, 3.234550982, 1]]
#
# class_val=0
# size=5
# p=1.000
# score=1.000
# class_val=1
# size=5
# p=0.000
# score=1.000
# class_val=0
# size=5
# p=0.000
# score=0.000
# class_val=1
# size=5
# p=1.000
# score=1.000
# X1 < 6.642 Gini=0.000
# index=0  value=6.642
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0]] [[7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=2
# p=0.500
# score=0.250
# class_val=1
# size=2
# p=0.500
# score=0.500
# class_val=0
# size=8
# p=0.500
# score=0.250
# class_val=1
# size=8
# p=0.500
# score=0.500
# X2 < 1.785 Gini=0.500
# index=1  value=1.785
# [[1.728571309, 1.169761413, 0], [7.444542326, 0.476683375, 1]] [[2.771244718, 1.784783929, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=1
# p=0.000
# score=0.000
# class_val=1
# size=1
# p=1.000
# score=1.000
# class_val=0
# size=9
# p=0.556
# score=0.309
# class_val=1
# size=9
# p=0.444
# score=0.506
# X2 < 1.170 Gini=0.444
# index=1  value=1.170
# [[7.444542326, 0.476683375, 1]] [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=5
# p=0.800
# score=0.640
# class_val=1
# size=5
# p=0.200
# score=0.680
# class_val=0
# size=5
# p=0.200
# score=0.040
# class_val=1
# size=5
# p=0.800
# score=0.680
# X2 < 2.813 Gini=0.320
# index=1  value=2.813
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.444542326, 0.476683375, 1]] [[3.678319846, 2.81281357, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=4
# p=0.750
# score=0.562
# class_val=1
# size=4
# p=0.250
# score=0.625
# class_val=0
# size=6
# p=0.333
# score=0.111
# class_val=1
# size=6
# p=0.667
# score=0.556
# X2 < 2.620 Gini=0.417
# index=1  value=2.620
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [2.999208922, 2.209014212, 0], [7.444542326, 0.476683375, 1]] [[3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=3
# p=0.667
# score=0.444
# class_val=1
# size=3
# p=0.333
# score=0.556
# class_val=0
# size=7
# p=0.429
# score=0.184
# class_val=1
# size=7
# p=0.571
# score=0.510
# X2 < 2.209 Gini=0.476
# index=1  value=2.209
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [7.444542326, 0.476683375, 1]] [[3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=6
# p=0.833
# score=0.694
# class_val=1
# size=6
# p=0.167
# score=0.722
# class_val=0
# size=4
# p=0.000
# score=0.000
# class_val=1
# size=4
# p=1.000
# score=1.000
# X2 < 3.163 Gini=0.167
# index=1  value=3.163
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.444542326, 0.476683375, 1]] [[7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=9
# p=0.556
# score=0.309
# class_val=1
# size=9
# p=0.444
# score=0.506
# class_val=0
# size=1
# p=0.000
# score=0.000
# class_val=1
# size=1
# p=1.000
# score=1.000
# X2 < 3.339 Gini=0.444
# index=1  value=3.339
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]] [[9.00220326, 3.339047188, 1]]
#
# class_val=0
# size=10
# p=0.500
# score=0.250
# class_val=1
# size=10
# p=0.500
# score=0.500
# X2 < 0.477 Gini=0.500
# index=1  value=0.477
# [] [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [9.00220326, 3.339047188, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=7
# p=0.714
# score=0.510
# class_val=1
# size=7
# p=0.286
# score=0.592
# class_val=0
# size=3
# p=0.000
# score=0.000
# class_val=1
# size=3
# p=1.000
# score=1.000
# X2 < 3.235 Gini=0.286
# index=1  value=3.235
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [7.444542326, 0.476683375, 1]] [[9.00220326, 3.339047188, 1], [10.12493903, 3.234550982, 1], [6.642287351, 3.319983761, 1]]
#
# class_val=0
# size=8
# p=0.625
# score=0.391
# class_val=1
# size=8
# p=0.375
# score=0.531
# class_val=0
# size=2
# p=0.000
# score=0.000
# class_val=1
# size=2
# p=1.000
# score=1.000
# X2 < 3.320 Gini=0.375
# index=1  value=3.320
# [[2.771244718, 1.784783929, 0], [1.728571309, 1.169761413, 0], [3.678319846, 2.81281357, 0], [3.961043357, 2.61995032, 0], [2.999208922, 2.209014212, 0], [7.497545867, 3.162953546, 1], [7.444542326, 0.476683375, 1], [10.12493903, 3.234550982, 1]] [[9.00220326, 3.339047188, 1], [6.642287351, 3.319983761, 1]]
#
# Split: [X1 < 6.642]
